# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/hp/Downloads/nba.csv")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.0    47
# 25.0    45
# 27.0    41
# 23.0    41
# 26.0    36
# 28.0    31
# 30.0    31
# 29.0    28
# 22.0    26
# 31.0    22
# 21.0    19
# 20.0    19
# 33.0    14
# 32.0    13
# 34.0    10
# 36.0    10
# 35.0     9
# 37.0     4
# 38.0     4
# 40.0     3
# 39.0     2
# 19.0     2
# Name: count, dtype: int64

# %%
df.loc[df['Age']> 30]
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 19      Jarrett Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# 31      Lou Amundson         New York Knicks    17.0       PF  33.0    6-9
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 34     Jose Calderon         New York Knicks     3.0       PG  34.0    6-3
# 43     Sasha Vujacic         New York Knicks    18.0       SG  32.0    6-7
# ..               ...                     ...     ...      ...   ...    ...
# 406  Tayshaun Prince  Minnesota Timberwolves    12.0       SF  36.0    6-9
# 413    Nick Collison   Oklahoma City Thunder     4.0       PF  35.0   6-10
# 415       Randy Foye   Oklahoma City Thunder     6.0       SG  32.0    6-4
# 420    Nazr Mohammed   Oklahoma City Thunder    13.0        C  38.0   6-10
# 434      Chris Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
#
#      Weight           College      Salary
# ...

# %%
df.loc[df['Team']=='Phoenix Suns']
# Out:
#                 Name          Team  Number Position   Age Height  Weight  \
# 121     Eric Bledsoe  Phoenix Suns     2.0       PG  26.0    6-1   190.0
# 122     Devin Booker  Phoenix Suns     1.0       SG  19.0    6-6   206.0
# 123   Chase Budinger  Phoenix Suns    10.0       SF  28.0    6-7   209.0
# 124   Tyson Chandler  Phoenix Suns     4.0        C  33.0    7-1   240.0
# 125   Archie Goodwin  Phoenix Suns    20.0       SG  21.0    6-5   200.0
# 126     John Jenkins  Phoenix Suns    23.0       SG  25.0    6-4   215.0
# 127   Brandon Knight  Phoenix Suns     3.0       PG  24.0    6-3   189.0
# 128         Alex Len  Phoenix Suns    21.0        C  22.0    7-1   260.0
# 129        Jon Leuer  Phoenix Suns    30.0       PF  27.0   6-10   228.0
# 130     Phil Pressey  Phoenix Suns    25.0       PG  25.0   5-11   175.0
# 131     Ronnie Price  Phoenix Suns    14.0       PG  32.0    6-2   190.0
# 132  Mirza Teletovic  Phoenix Suns    35.0       PF  30.0    6-9   242.0
# ...

# %%
df.loc[(df['Age'] > 25) & (df['Salary'] > 5000000)]
# Out:
#                   Name                    Team  Number Position   Age Height  \
# 5         Amir Johnson          Boston Celtics    90.0       PF  29.0    6-9
# 11       Isaiah Thomas          Boston Celtics     4.0       PG  27.0    5-9
# 19        Jarrett Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# 23         Brook Lopez           Brooklyn Nets    11.0        C  28.0    7-0
# 29      Thaddeus Young           Brooklyn Nets    30.0       PF  27.0    6-8
# ..                 ...                     ...     ...      ...   ...    ...
# 426  Russell Westbrook   Oklahoma City Thunder     0.0       PG  27.0    6-3
# 431           Ed Davis  Portland Trail Blazers    17.0        C  27.0   6-10
# 433   Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0    6-5
# 434        Chris Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
# 448     Gordon Hayward               Utah Jazz    20.0       SF  26.0    6-8
#
#      Weight           College      Salary
# ...

# %%
df.loc[(df['Age'] > 30) | (df['Team'] == 'Brooklyn Nets')]
# Out:
#                         Name                    Team  Number Position   Age  \
# 15          Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# ..                       ...                     ...     ...      ...   ...
# 406          Tayshaun Prince  Minnesota Timberwolves    12.0       SF  36.0
# 413            Nick Collison   Oklahoma City Thunder     4.0       PF  35.0
# 415               Randy Foye   Oklahoma City Thunder     6.0       SG  32.0
# 420            Nazr Mohammed   Oklahoma City Thunder    13.0        C  38.0
# 434              Chris Kaman  Portland Trail Blazers    35.0        C  34.0
#
#     Height  Weight           College     Salary
# ...

# %%
df.loc[df['Age']>30]
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 19      Jarrett Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# 31      Lou Amundson         New York Knicks    17.0       PF  33.0    6-9
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 34     Jose Calderon         New York Knicks     3.0       PG  34.0    6-3
# 43     Sasha Vujacic         New York Knicks    18.0       SG  32.0    6-7
# ..               ...                     ...     ...      ...   ...    ...
# 406  Tayshaun Prince  Minnesota Timberwolves    12.0       SF  36.0    6-9
# 413    Nick Collison   Oklahoma City Thunder     4.0       PF  35.0   6-10
# 415       Randy Foye   Oklahoma City Thunder     6.0       SG  32.0    6-4
# 420    Nazr Mohammed   Oklahoma City Thunder    13.0        C  38.0   6-10
# 434      Chris Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
#
#      Weight           College      Salary
# ...

# %%
df['Team']=='Phoenix Suns'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Name: Team, Length: 458, dtype: bool

# %%
df['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Philadelphia 76ers        15
# Toronto Raptors           15
# Golden State Warriors     15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Phoenix Suns              15
# Sacramento Kings          15
# Chicago Bulls             15
# Cleveland Cavaliers       15
# Detroit Pistons           15
# Indiana Pacers            15
# Dallas Mavericks          15
# Houston Rockets           15
# San Antonio Spurs         15
# Atlanta Hawks             15
# Charlotte Hornets         15
# Miami Heat                15
# Washington Wizards        15
# Denver Nuggets            15
# Oklahoma City Thunder     15
# Portland Trail Blazers    15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
df1=df.loc[df['Team']=='Phoenix Suns']
df1
# Out:
#                 Name          Team  Number Position   Age Height  Weight  \
# 121     Eric Bledsoe  Phoenix Suns     2.0       PG  26.0    6-1   190.0
# 122     Devin Booker  Phoenix Suns     1.0       SG  19.0    6-6   206.0
# 123   Chase Budinger  Phoenix Suns    10.0       SF  28.0    6-7   209.0
# 124   Tyson Chandler  Phoenix Suns     4.0        C  33.0    7-1   240.0
# 125   Archie Goodwin  Phoenix Suns    20.0       SG  21.0    6-5   200.0
# 126     John Jenkins  Phoenix Suns    23.0       SG  25.0    6-4   215.0
# 127   Brandon Knight  Phoenix Suns     3.0       PG  24.0    6-3   189.0
# 128         Alex Len  Phoenix Suns    21.0        C  22.0    7-1   260.0
# 129        Jon Leuer  Phoenix Suns    30.0       PF  27.0   6-10   228.0
# 130     Phil Pressey  Phoenix Suns    25.0       PG  25.0   5-11   175.0
# 131     Ronnie Price  Phoenix Suns    14.0       PG  32.0    6-2   190.0
# 132  Mirza Teletovic  Phoenix Suns    35.0       PF  30.0    6-9   242.0
# ...

# %%
df1['Team'].value_counts()
# Out:
# Team
# Phoenix Suns    15
# Name: count, dtype: int64

# %%
df1=df.loc[df['Age']>30]
df1
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 19      Jarrett Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# 31      Lou Amundson         New York Knicks    17.0       PF  33.0    6-9
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 34     Jose Calderon         New York Knicks     3.0       PG  34.0    6-3
# 43     Sasha Vujacic         New York Knicks    18.0       SG  32.0    6-7
# ..               ...                     ...     ...      ...   ...    ...
# 406  Tayshaun Prince  Minnesota Timberwolves    12.0       SF  36.0    6-9
# 413    Nick Collison   Oklahoma City Thunder     4.0       PF  35.0   6-10
# 415       Randy Foye   Oklahoma City Thunder     6.0       SG  32.0    6-4
# 420    Nazr Mohammed   Oklahoma City Thunder    13.0        C  38.0   6-10
# 434      Chris Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
#
#      Weight           College      Salary
# ...

# %%
df1.shape
# Out:
# (91, 9)

# %%
df['Age'].unique()
# Out:
# array([25., 27., 22., 29., 21., 24., 20., 26., 28., 32., 23., 30., 33.,
#        34., 37., 36., 31., 38., 39., 19., 35., 40., nan])

# %%
df['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Philadelphia 76ers        15
# Toronto Raptors           15
# Golden State Warriors     15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Phoenix Suns              15
# Sacramento Kings          15
# Chicago Bulls             15
# Cleveland Cavaliers       15
# Detroit Pistons           15
# Indiana Pacers            15
# Dallas Mavericks          15
# Houston Rockets           15
# San Antonio Spurs         15
# Atlanta Hawks             15
# Charlotte Hornets         15
# Miami Heat                15
# Washington Wizards        15
# Denver Nuggets            15
# Oklahoma City Thunder     15
# Portland Trail Blazers    15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
df2=df.loc[(df['Age']>25) & (df['Salary']>5000000)]
df2
# Out:
#                   Name                    Team  Number Position   Age Height  \
# 5         Amir Johnson          Boston Celtics    90.0       PF  29.0    6-9
# 11       Isaiah Thomas          Boston Celtics     4.0       PG  27.0    5-9
# 19        Jarrett Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# 23         Brook Lopez           Brooklyn Nets    11.0        C  28.0    7-0
# 29      Thaddeus Young           Brooklyn Nets    30.0       PF  27.0    6-8
# ..                 ...                     ...     ...      ...   ...    ...
# 426  Russell Westbrook   Oklahoma City Thunder     0.0       PG  27.0    6-3
# 431           Ed Davis  Portland Trail Blazers    17.0        C  27.0   6-10
# 433   Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0    6-5
# 434        Chris Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
# 448     Gordon Hayward               Utah Jazz    20.0       SF  26.0    6-8
#
#      Weight           College      Salary
# ...

# %%
df2['Age'].unique()
# Out:
# array([29., 27., 32., 28., 30., 34., 26., 31., 36., 37., 33., 35., 40.])

# %%
df2['Salary'].unique()
# Out:
# array([12000000.,  6912869.,  6300000., 19689000., 11235955.,  8000000.,
#        22875000.,  7402812., 12650000.,  6500000., 13600000., 10050000.,
#         6268675., 13800000., 11370786., 14260870., 11710456.,  5543725.,
#        15501000.,  5675000.,  9650000., 18907726., 21468695.,  7085000.,
#        25000000., 15592217.,  7000000.,  5219169., 13500000., 13000000.,
#         5500000.,  6060606.,  5013559., 12403101.,  7700000.,  9500000.,
#        16407500.,  7448760.,  8500000., 13400000., 20093064.,  8193029.,
#        22970500., 13913044.,  6270000., 10300000., 17120106.,  6600000.,
#         8333334.,  5200000., 15361500.,  5378974.,  8193030.,  6486486.,
#         8229375., 15756438., 22359364.,  5158539.,  9588426., 19688000.,
#         9638555.,  5464000.,  9213483., 10734586., 15514031.,  7500000.,
#         5250000., 10000000., 13437500.,  5746479., 18671659.,  9756250.,
#        13125306.,  6110034., 22192730., 10151612., 14783000., 20000000.,
# ...

# %%
df3=df.loc[(df['Age']>30)| (df['Team']=='Brooklyn Nets')]
df3
# Out:
#                         Name                    Team  Number Position   Age  \
# 15          Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# ..                       ...                     ...     ...      ...   ...
# 406          Tayshaun Prince  Minnesota Timberwolves    12.0       SF  36.0
# 413            Nick Collison   Oklahoma City Thunder     4.0       PF  35.0
# 415               Randy Foye   Oklahoma City Thunder     6.0       SG  32.0
# 420            Nazr Mohammed   Oklahoma City Thunder    13.0        C  38.0
# 434              Chris Kaman  Portland Trail Blazers    35.0        C  34.0
#
#     Height  Weight           College     Salary
# ...

# %%
df3['Age'].unique()
# Out:
# array([27., 24., 28., 21., 32., 22., 26., 23., 25., 33., 34., 37., 36.,
#        31., 38., 39., 35., 40.])

# %%
df['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Philadelphia 76ers        15
# Toronto Raptors           15
# Golden State Warriors     15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Phoenix Suns              15
# Sacramento Kings          15
# Chicago Bulls             15
# Cleveland Cavaliers       15
# Detroit Pistons           15
# Indiana Pacers            15
# Dallas Mavericks          15
# Houston Rockets           15
# San Antonio Spurs         15
# Atlanta Hawks             15
# Charlotte Hornets         15
# Miami Heat                15
# Washington Wizards        15
# Denver Nuggets            15
# Oklahoma City Thunder     15
# Portland Trail Blazers    15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
dfa=df.loc[df['Team'].isin(['Brooklyn Nets','Portland Trail Blazers'])]

# %%
dfa
# Out:
#                         Name                    Team  Number Position   Age  \
# 15          Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 20            Sergey Karasev           Brooklyn Nets    10.0       SG  22.0
# 21           Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 22              Shane Larkin           Brooklyn Nets     0.0       PG  23.0
# 23               Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 24          Chris McCullough           Brooklyn Nets     1.0       PF  21.0
# 25               Willie Reed           Brooklyn Nets    33.0       PF  26.0
# ...

# %%
dfc=df.loc[df['Age'].between(25,30)]
dfc
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 450     Joe Ingles       Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College      Salary
# 0                Texas   7730337.0
# ...

# %%
dfb=df.loc[df['Salary'].isnull()]
dfb
# Out:
#                Name                    Team  Number Position   Age Height  \
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
# ...

# %%
dfd=df.loc[df['Salary'].notnull()]
dfd
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College      Salary
# 0            Texas   7730337.0
# ...

# %%
df.loc[df['Team'].isin(['Brooklyn Nets','Portland Trail Blazers'])]
# Out:
#                         Name                    Team  Number Position   Age  \
# 15          Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 20            Sergey Karasev           Brooklyn Nets    10.0       SG  22.0
# 21           Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 22              Shane Larkin           Brooklyn Nets     0.0       PG  23.0
# 23               Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 24          Chris McCullough           Brooklyn Nets     1.0       PF  21.0
# 25               Willie Reed           Brooklyn Nets    33.0       PF  26.0
# ...

# %%
dfs=df.loc[df['Age'].between(25,30)]
dfs
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 450     Joe Ingles       Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College      Salary
# 0                Texas   7730337.0
# ...

# %%
df4=df.loc[df['Salary'].isnull()]
df4.shape
# Out:
# (12, 9)

# %%
df4
# Out:
#                Name                    Team  Number Position   Age Height  \
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
# ...

# %%
df5=df.loc[df['Salary'].notnull()]
df5
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College      Salary
# 0            Texas   7730337.0
# ...

# %%
df.loc[0,'Salary']=999999

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas   999999.0
# ...

# %%
df.loc[df['Team']=='Lakers','Team']='LA Lakers'

# %%
df.loc[df['Age']>30,'Senior']='Yes'

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary Senior
# 0                Texas   999999.0    NaN
# ...

# %%
df.loc[df['Age']<30,'Senior']='No'

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary Senior
# 0                Texas   999999.0     No
# ...

# %%
df['Team'].unique()
# Out:
# <StringArray>
# [        'Boston Celtics',          'Brooklyn Nets',        'New York Knicks',
#      'Philadelphia 76ers',        'Toronto Raptors',  'Golden State Warriors',
#    'Los Angeles Clippers',     'Los Angeles Lakers',           'Phoenix Suns',
#        'Sacramento Kings',          'Chicago Bulls',    'Cleveland Cavaliers',
#         'Detroit Pistons',         'Indiana Pacers',        'Milwaukee Bucks',
#        'Dallas Mavericks',        'Houston Rockets',      'Memphis Grizzlies',
#    'New Orleans Pelicans',      'San Antonio Spurs',          'Atlanta Hawks',
#       'Charlotte Hornets',             'Miami Heat',          'Orlando Magic',
#      'Washington Wizards',         'Denver Nuggets', 'Minnesota Timberwolves',
#   'Oklahoma City Thunder', 'Portland Trail Blazers',              'Utah Jazz',
#                       nan]
# Length: 31, dtype: str

# %%
df.loc[df['Team']=='Toronto Raptors','Team'] = 'TR'
df.shape
# Out:
# (458, 10)

# %%
df.head(6)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary Senior
# 0              Texas    999999.0     No
# 1          Marquette   6796117.0     No
# 2  Boston University         NaN     No
# 3      Georgia State   1148640.0     No
# 4                NaN   5000000.0     No
# 5                NaN  12000000.0     No

# %%
df.iloc[5,2]
# Out:
# np.float64(90.0)

# %%
df.iloc[0,0]
# Out:
# 'Avery Bradley'

# %%
df.iloc[0:5]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary Senior
# 0              Texas   999999.0     No
# 1          Marquette  6796117.0     No
# 2  Boston University        NaN     No
# 3      Georgia State  1148640.0     No
# 4                NaN  5000000.0     No

# %%
df.iloc[0:5,0:3]
# Out:
#             Name            Team  Number
# 0  Avery Bradley  Boston Celtics     0.0
# 1    Jae Crowder  Boston Celtics    99.0
# 2   John Holland  Boston Celtics    30.0
# 3    R.J. Hunter  Boston Celtics    28.0
# 4  Jonas Jerebko  Boston Celtics     8.0

# %%
df.iloc[: ,0:2]
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
df.iloc[5:10, :]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#           College      Salary Senior
# 5             NaN  12000000.0     No
# 6             LSU   1170960.0     No
# 7         Gonzaga   2165160.0     No
# 8      Louisville   1824360.0     No
# 9  Oklahoma State   3431040.0     No

# %%
df.iloc[[1,2,3]]
# Out:
#            Name            Team  Number Position   Age Height  Weight  \
# 1   Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2  John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3   R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary Senior
# 1          Marquette  6796117.0     No
# 2  Boston University        NaN     No
# 3      Georgia State  1148640.0     No

# %%
df.iloc[[1,2,3],[0,2]]
# Out:
#            Name  Number
# 1   Jae Crowder    99.0
# 2  John Holland    30.0
# 3   R.J. Hunter    28.0

# %%
df.iloc[[0,2,4], :]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary Senior
# 0              Texas   999999.0     No
# 2  Boston University        NaN     No
# 4                NaN  5000000.0     No

# %%
df.iloc[:, [1,3,5]]
# Out:
#                Team Position Height
# 0    Boston Celtics       PG    6-2
# 1    Boston Celtics       SF    6-6
# 2    Boston Celtics       SG    6-5
# 3    Boston Celtics       SG    6-5
# 4    Boston Celtics       PF   6-10
# ..              ...      ...    ...
# 453       Utah Jazz       PG    6-3
# 454       Utah Jazz       PG    6-1
# 455       Utah Jazz        C    7-3
# 456       Utah Jazz        C    7-0
# 457             NaN      NaN    NaN
#
# [458 rows x 3 columns]

# %%
x='Artificial Intelligence'
x[2:10]
# Out:
# 'tificial'

# %%
x[2:10:2]
# Out:
# 'tfca'

# %%
df[df['Age'] > 25]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 11   Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# 12     Evan Turner  Boston Celtics    11.0       SG  27.0    6-7   220.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 450     Joe Ingles       Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College      Salary Senior
# 2    Boston University         NaN     No
# ...
